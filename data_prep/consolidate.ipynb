# %%
import pandas as pd

# %%
well_code_list = [7405, 7078, 5599, 5351, 7289]

df_list = [pd.read_csv(f'../datasets/well_data/well_{well_code}_data.csv') for well_code in well_code_list]

df = pd.concat(df_list)

# %%
df
# Out:
#         DATEPRD  AVG_DOWNHOLE_PRESSURE  AVG_DOWNHOLE_TEMPERATURE  \
# 0    2014-04-07                0.00000                   0.00000
# 1    2014-04-08                0.00000                   0.00000
# 2    2014-04-09                0.00000                   0.00000
# 3    2014-04-10                0.00000                   0.00000
# 4    2014-04-11              310.37614                  96.87589
# ..          ...                    ...                       ...
# 973  2016-09-13              345.90677                  90.03433
# 974  2016-09-14              345.90677                  90.03433
# 975  2016-09-15              345.90677                  90.03433
# 976  2016-09-16              345.90677                  90.03433
# 977  2016-09-17              345.90677                  90.03433
#
#      AVG_DP_TUBING  AVG_ANNULUS_PRESS  AVG_CHOKE_SIZE_P  AVG_WHP_P  AVG_WHT_P  \
# 0          0.00000                0.0          0.000000    0.00000    0.00000
# ...

# %%
fluid_list = ['OIL', 'GAS']

for fluid in fluid_list:
    fluid_df = df[['DATEPRD', f'BORE_{fluid}_VOL']].groupby('DATEPRD').sum()
    fluid_df.to_csv(f'../datasets/consolidated_data/{fluid.lower()}_data.csv')
